# %%
from sklearn import preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os


# encode the classes(setosa, versicolor, virginica) into [1,0,0], [0,1,0], [0,0,1]
# and store the classes by n(donate the number of the classes) fields
def encode_text_dummy(df, name):
    dummies = pd.get_dummies(df[name])
    
    for x in dummies.columns:
        dummy_name = '{}-{}'.format(str(name), str(x))
        df[dummy_name] = dummies[x]
    df.drop(name, axis=1, inplace=True)
    
# encode the classes  into the binary type, 1 if the class is target class, nor 0
def encode_text_single_dummy(df, name, target_vals):
    for val in target_vals:
        is_value = lambda x: 1 if str(x) == str(val) else 0
        val_name = 'dummy-%s'%val
        df[dummy_name] = df[name].apply(is_value)
    
# encode the classes(setosa, versicolor, virginica) into 1, 2, 3
def encode_text_index(df, name):
    le = preprocessing.LabelEncoder()
    encode_name = 'le-%s'%name
    df[encode_name] = le.fit_transform(df[name])
    return le.classes_

# encode a numeric column as zscores
def encode_numeric_zscore(df, name, mean=None, sd=None):
    mean = mean or df[name].mean()
    sd = sd or df[name].std()
    
    df[name] = (df[name] - mean)/sd

# convert all missing value in specific column to the median
def missing_median(df, name):
    med = df[name].median()
    df[name] = df[name].fillna(med)

# convert all missing value in specific column to the default value
def missing_default(df, name, default_value):
    df[name] = df[name].fillna(default_value)
    
# convert pandas dataFrame to x, y inputs that tensorflow needs
def to_xy(df, target):
    results = []
    for c in df.columns:
        if c != target:
            results.append(c)
    
    target_type = df[target].dtypes[0] if hasattr(df[target].dtypes, '__iter__') else df[target].dtypes
    # encode to int for classification, otherwise float, TensorFlow prefer 32bits
    if target_type in (np.int64, np.int32):
        # classification
        dummies = pd.get_dummies(df[target])
        return df.as_matrix(results).astype(np.float32), dummies.as_matrix().astype(np.float32)
    else:
        # Regression
        return df.as_matrix(results).astype(np.float32), df.as_matrix(target).astype(np.float32)

# plot chart of Regression
def chart_regression(pred, y, sort=True):
    df = pd.DataFrame({'pred': pred, 'y': y.flatten()})
    if sort:
        df.sort_values(by=['y'], inpalce=True)
    plt.plot(df['y'].tolist(), label='expected')
    plt.plot(df['pred'].tolist(), label='predict')
    plt.ylabel('output')
    plt.legend()
    plt.show()

# remove all rows that deviate over the sd 
def remove_outliers(df, name, sd):
    drop_rows = df.index[(np.abs(df[name] - df[name].mean()) >= (sd*df[name].std()))]
    df.drop(drop_rows, axis=0, inplace=True)
    return df

# encode a column to a range between normalize_low and normalized_high
def encode_numeric_range(df, name, normalized_low=-1, normalized_high=1,
                         data_low=None, data_high=None):
    if data_low is None:
        data_low = df[name].min()
        data_high = df[name].max()
    
    df[name] = (df[name]-data_low)*(normalized_high-normalized_low)/(data_high-data_low) + normalized_low

    return df[name]

# %%
# load data and normalize 

import tensorflow.contrib.learn as sklflow
import pandas as pd
import os 
import numpy as np
from sklearn import metrics
from scipy.stats import zscore

path = '../data/'

file = os.path.join(path, 'auto-mpg.csv')

# %%
mpg_df = pd.read_csv(file, encoding='utf8', na_values=['NA', '?'])

'''
find special column and row contains NAN
mpg_df.isnull().any()  # return column that contain NaN

mpg_df[mpg_df[colname].isnull()]

'''
missing_median(mpg_df, 'horsepower')
mpg_df.drop('name', axis=1, inplace=True)


# remove outliers in mpg
print("the length of MPG before dropped : %s"%len(mpg_df))

remove_outliers(mpg_df, 'mpg', 2)

print("the length of MPG after dropped : %s"%len(mpg_df))
# Out:
# the length of MPG before dropped : 398
# the length of MPG after dropped : 388

# %%
mpg_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## Training with a Validation Set and Early Stopping
#
# split dataset into training data and validation dataset,

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.callbacks import EarlyStopping

# %%
# load data 
iris_df = pd.read_csv('../data/iris.csv', na_values=['NA', '?'])
iris_df.head()
# Out:
#    sepal_l  sepal_w  petal_l  petal_w      species
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
# check NaN column 
iris_df.isnull().any()
# Out:
# sepal_l    False
# sepal_w    False
# petal_l    False
# petal_w    False
# species    False
# dtype: bool

# %%
# encode the species
cl_ = encode_text_index(iris_df, 'species')
iris_df.head()
# Out:
#    sepal_l  sepal_w  petal_l  petal_w      species  le-species
# 0      5.1      3.5      1.4      0.2  Iris-setosa           0
# 1      4.9      3.0      1.4      0.2  Iris-setosa           0
# 2      4.7      3.2      1.3      0.2  Iris-setosa           0
# 3      4.6      3.1      1.5      0.2  Iris-setosa           0
# 4      5.0      3.6      1.4      0.2  Iris-setosa           0

# %%
# generate valid data from dataframe
iris_df.drop('species', axis=1, inplace=True)
x, y = to_xy(iris_df, 'le-species')

# %%
x[:3], y[:3]
# Out:
# (array([[ 5.0999999 ,  3.5       ,  1.39999998,  0.2       ],
#         [ 4.9000001 ,  3.        ,  1.39999998,  0.2       ],
#         [ 4.69999981,  3.20000005,  1.29999995,  0.2       ]], dtype=float32),
#  array([[ 1.,  0.,  0.],
#         [ 1.,  0.,  0.],
#         [ 1.,  0.,  0.]], dtype=float32))

# %%
cl_
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# train data with sequantial model

# split dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=32)

model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], activation='relu'))  # input layer and hidden 1
model.add(Dense(25, activation='relu')) # hidden 2
model.add(Dense(y.shape[1], activation='softmax'))

# define the loss function and optimizer
model.compile(loss='categorical_crossentropy', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, mode='auto')

model.fit(x, y, validation_data=(x_test, y_test), callbacks=[monitor], verbose=2, epochs=1000)
# Out:
# Train on 150 samples, validate on 38 samples
# Epoch 1/1000
# 0s - loss: 1.3831 - val_loss: 1.2252
# Epoch 2/1000
# 0s - loss: 1.1690 - val_loss: 1.0890
# Epoch 3/1000
# 0s - loss: 1.0651 - val_loss: 1.0404
# Epoch 4/1000
# 0s - loss: 1.0330 - val_loss: 1.0427
# Epoch 5/1000
# 0s - loss: 1.0305 - val_loss: 1.0316
# Epoch 6/1000
# 0s - loss: 1.0101 - val_loss: 1.0043
# Epoch 7/1000
# 0s - loss: 0.9855 - val_loss: 0.9820
# Epoch 8/1000
# 0s - loss: 0.9699 - val_loss: 0.9691
# Epoch 9/1000
# 0s - loss: 0.9589 - val_loss: 0.9575
# Epoch 10/1000
# 0s - loss: 0.9484 - val_loss: 0.9422
# Epoch 11/1000
# 0s - loss: 0.9323 - val_loss: 0.9282
# Epoch 12/1000
# 0s - loss: 0.9199 - val_loss: 0.9139
# Epoch 13/1000
# 0s - loss: 0.9057 - val_loss: 0.8982
# Epoch 14/1000
# 0s - loss: 0.8931 - val_loss: 0.8820
# Epoch 15/1000
# 0s - loss: 0.8799 - val_loss: 0.8696
# Epoch 16/1000
# 0s - loss: 0.8659 - val_loss: 0.8529
# Epoch 17/1000
# 0s - loss: 0.8513 - val_loss: 0.8393
# Epoch 18/1000
# 0s - loss: 0.8366 - val_loss: 0.8232
# Epoch 19/1000
# 0s - loss: 0.8233 - val_loss: 0.8055
# Epoch 20/1000
# 0s - loss: 0.8065 - val_loss: 0.7887
# Epoch 21/1000
# 0s - loss: 0.7910 - val_loss: 0.7737
# Epoch 22/1000
# 0s - loss: 0.7761 - val_loss: 0.7552
# Epoch 23/1000
# 0s - loss: 0.7592 - val_loss: 0.7381
# Epoch 24/1000
# 0s - loss: 0.7430 - val_loss: 0.7206
# Epoch 25/1000
# 0s - loss: 0.7273 - val_loss: 0.7043
# Epoch 26/1000
# 0s - loss: 0.7098 - val_loss: 0.6849
# Epoch 27/1000
# 0s - loss: 0.6915 - val_loss: 0.6627
# Epoch 28/1000
# 0s - loss: 0.6692 - val_loss: 0.6440
# Epoch 29/1000
# 0s - loss: 0.6540 - val_loss: 0.6273
# Epoch 30/1000
# 0s - loss: 0.6367 - val_loss: 0.6139
# Epoch 31/1000
# 0s - loss: 0.6238 - val_loss: 0.5961
# Epoch 32/1000
# 0s - loss: 0.6062 - val_loss: 0.5807
# Epoch 33/1000
# 0s - loss: 0.5932 - val_loss: 0.5627
# Epoch 34/1000
# 0s - loss: 0.5785 - val_loss: 0.5465
# Epoch 35/1000
# 0s - loss: 0.5646 - val_loss: 0.5320
# Epoch 36/1000
# 0s - loss: 0.5505 - val_loss: 0.5193
# Epoch 37/1000
# 0s - loss: 0.5382 - val_loss: 0.5069
# Epoch 38/1000
# 0s - loss: 0.5271 - val_loss: 0.4949
# Epoch 39/1000
# 0s - loss: 0.5149 - val_loss: 0.4804
# Epoch 40/1000
# 0s - loss: 0.5043 - val_loss: 0.4682
# Epoch 41/1000
# 0s - loss: 0.4928 - val_loss: 0.4579
# Epoch 42/1000
# 0s - loss: 0.4810 - val_loss: 0.4494
# Epoch 43/1000
# 0s - loss: 0.4743 - val_loss: 0.4432
# Epoch 44/1000
# 0s - loss: 0.4645 - val_loss: 0.4312
# Epoch 45/1000
# 0s - loss: 0.4572 - val_loss: 0.4202
# Epoch 46/1000
# 0s - loss: 0.4468 - val_loss: 0.4110
# Epoch 47/1000
# 0s - loss: 0.4386 - val_loss: 0.4022
# Epoch 48/1000
# 0s - loss: 0.4296 - val_loss: 0.3949
# Epoch 49/1000
# 0s - loss: 0.4229 - val_loss: 0.3871
# Epoch 50/1000
# 0s - loss: 0.4149 - val_loss: 0.3804
# Epoch 51/1000
# 0s - loss: 0.4090 - val_loss: 0.3742
# Epoch 52/1000
# 0s - loss: 0.4036 - val_loss: 0.3682
# Epoch 53/1000
# 0s - loss: 0.3959 - val_loss: 0.3611
# Epoch 54/1000
# 0s - loss: 0.3903 - val_loss: 0.3554
# Epoch 55/1000
# 0s - loss: 0.3839 - val_loss: 0.3493
# Epoch 56/1000
# 0s - loss: 0.3789 - val_loss: 0.3424
# Epoch 57/1000
# 0s - loss: 0.3732 - val_loss: 0.3372
# Epoch 58/1000
# 0s - loss: 0.3683 - val_loss: 0.3318
# Epoch 59/1000
# 0s - loss: 0.3632 - val_loss: 0.3289
# Epoch 60/1000
# 0s - loss: 0.3575 - val_loss: 0.3227
# Epoch 61/1000
# 0s - loss: 0.3524 - val_loss: 0.3167
# Epoch 62/1000
# 0s - loss: 0.3470 - val_loss: 0.3126
# Epoch 63/1000
# 0s - loss: 0.3420 - val_loss: 0.3079
# Epoch 64/1000
# 0s - loss: 0.3372 - val_loss: 0.3028
# Epoch 65/1000
# 0s - loss: 0.3321 - val_loss: 0.2975
# Epoch 66/1000
# 0s - loss: 0.3282 - val_loss: 0.2923
# Epoch 67/1000
# 0s - loss: 0.3231 - val_loss: 0.2888
# Epoch 68/1000
# 0s - loss: 0.3191 - val_loss: 0.2844
# Epoch 69/1000
# 0s - loss: 0.3163 - val_loss: 0.2831
# Epoch 70/1000
# 0s - loss: 0.3110 - val_loss: 0.2773
# Epoch 71/1000
# 0s - loss: 0.3068 - val_loss: 0.2701
# Epoch 72/1000
# 0s - loss: 0.3034 - val_loss: 0.2659
# Epoch 73/1000
# 0s - loss: 0.2964 - val_loss: 0.2636
# Epoch 74/1000
# 0s - loss: 0.2936 - val_loss: 0.2638
# Epoch 75/1000
# 0s - loss: 0.2895 - val_loss: 0.2562
# Epoch 76/1000
# 0s - loss: 0.2849 - val_loss: 0.2515
# Epoch 77/1000
# 0s - loss: 0.2863 - val_loss: 0.2459
# Epoch 78/1000
# 0s - loss: 0.2770 - val_loss: 0.2434
# Epoch 79/1000
# 0s - loss: 0.2720 - val_loss: 0.2432
# Epoch 80/1000
# 0s - loss: 0.2702 - val_loss: 0.2383
# Epoch 81/1000
# 0s - loss: 0.2677 - val_loss: 0.2347
# Epoch 82/1000
# 0s - loss: 0.2616 - val_loss: 0.2277
# Epoch 83/1000
# 0s - loss: 0.2583 - val_loss: 0.2243
# Epoch 84/1000
# 0s - loss: 0.2546 - val_loss: 0.2226
# Epoch 85/1000
# 0s - loss: 0.2504 - val_loss: 0.2190
# Epoch 86/1000
# 0s - loss: 0.2480 - val_loss: 0.2153
# Epoch 87/1000
# 0s - loss: 0.2425 - val_loss: 0.2102
# Epoch 88/1000
# 0s - loss: 0.2416 - val_loss: 0.2064
# Epoch 89/1000
# 0s - loss: 0.2396 - val_loss: 0.2069
# Epoch 90/1000
# 0s - loss: 0.2339 - val_loss: 0.2032
# Epoch 91/1000
# 0s - loss: 0.2304 - val_loss: 0.1981
# Epoch 92/1000
# 0s - loss: 0.2270 - val_loss: 0.1959
# Epoch 93/1000
# 0s - loss: 0.2243 - val_loss: 0.1931
# Epoch 94/1000
# 0s - loss: 0.2222 - val_loss: 0.1908
# Epoch 95/1000
# 0s - loss: 0.2181 - val_loss: 0.1870
# Epoch 96/1000
# 0s - loss: 0.2147 - val_loss: 0.1834
# Epoch 97/1000
# 0s - loss: 0.2165 - val_loss: 0.1793
# Epoch 98/1000
# 0s - loss: 0.2103 - val_loss: 0.1819
# Epoch 99/1000
# 0s - loss: 0.2099 - val_loss: 0.1824
# Epoch 100/1000
# 0s - loss: 0.2045 - val_loss: 0.1719
# Epoch 101/1000
# 0s - loss: 0.2021 - val_loss: 0.1694
# Epoch 102/1000
# 0s - loss: 0.1993 - val_loss: 0.1679
# Epoch 103/1000
# 0s - loss: 0.1968 - val_loss: 0.1670
# Epoch 104/1000
# 0s - loss: 0.1946 - val_loss: 0.1626
# Epoch 105/1000
# 0s - loss: 0.1916 - val_loss: 0.1609
# Epoch 106/1000
# 0s - loss: 0.1889 - val_loss: 0.1605
# Epoch 107/1000
# 0s - loss: 0.1870 - val_loss: 0.1602
# Epoch 108/1000
# 0s - loss: 0.1852 - val_loss: 0.1561
# Epoch 109/1000
# 0s - loss: 0.1822 - val_loss: 0.1523
# Epoch 110/1000
# 0s - loss: 0.1795 - val_loss: 0.1500
# Epoch 111/1000
# 0s - loss: 0.1777 - val_loss: 0.1482
# Epoch 112/1000
# 0s - loss: 0.1758 - val_loss: 0.1459
# Epoch 113/1000
# 0s - loss: 0.1753 - val_loss: 0.1477
# Epoch 114/1000
# 0s - loss: 0.1733 - val_loss: 0.1410
# Epoch 115/1000
# 0s - loss: 0.1699 - val_loss: 0.1408
# Epoch 116/1000
# 0s - loss: 0.1672 - val_loss: 0.1392
# Epoch 117/1000
# 0s - loss: 0.1658 - val_loss: 0.1373
# Epoch 118/1000
# 0s - loss: 0.1638 - val_loss: 0.1344
# Epoch 119/1000
# 0s - loss: 0.1626 - val_loss: 0.1338
# Epoch 120/1000
# 0s - loss: 0.1602 - val_loss: 0.1327
# Epoch 121/1000
# 0s - loss: 0.1590 - val_loss: 0.1289
# Epoch 122/1000
# 0s - loss: 0.1567 - val_loss: 0.1289
# Epoch 123/1000
# 0s - loss: 0.1554 - val_loss: 0.1287
# Epoch 124/1000
# 0s - loss: 0.1544 - val_loss: 0.1241
# Epoch 125/1000
# 0s - loss: 0.1513 - val_loss: 0.1241
# Epoch 126/1000
# 0s - loss: 0.1510 - val_loss: 0.1255
# Epoch 127/1000
# 0s - loss: 0.1490 - val_loss: 0.1202
# Epoch 128/1000
# 0s - loss: 0.1482 - val_loss: 0.1166
# Epoch 129/1000
# 0s - loss: 0.1459 - val_loss: 0.1195
# Epoch 130/1000
# 0s - loss: 0.1448 - val_loss: 0.1184
# Epoch 131/1000
# 0s - loss: 0.1428 - val_loss: 0.1149
# Epoch 132/1000
# 0s - loss: 0.1411 - val_loss: 0.1113
# Epoch 133/1000
# 0s - loss: 0.1411 - val_loss: 0.1111
# Epoch 134/1000
# 0s - loss: 0.1385 - val_loss: 0.1128
# Epoch 135/1000
# 0s - loss: 0.1377 - val_loss: 0.1105
# Epoch 136/1000
# 0s - loss: 0.1358 - val_loss: 0.1089
# Epoch 137/1000
# 0s - loss: 0.1349 - val_loss: 0.1073
# Epoch 138/1000
# 0s - loss: 0.1345 - val_loss: 0.1036
# Epoch 139/1000
# 0s - loss: 0.1323 - val_loss: 0.1053
# Epoch 140/1000
# 0s - loss: 0.1315 - val_loss: 0.1044
# Epoch 141/1000
# 0s - loss: 0.1312 - val_loss: 0.1080
# Epoch 142/1000
# 0s - loss: 0.1299 - val_loss: 0.1039
# Epoch 143/1000
# 0s - loss: 0.1274 - val_loss: 0.0977
# Epoch 144/1000
# 0s - loss: 0.1275 - val_loss: 0.0969
# Epoch 145/1000
# 0s - loss: 0.1254 - val_loss: 0.0997
# Epoch 146/1000
# 0s - loss: 0.1266 - val_loss: 0.1035
# Epoch 147/1000
# 0s - loss: 0.1261 - val_loss: 0.0934
# Epoch 148/1000
# 0s - loss: 0.1232 - val_loss: 0.0934
# Epoch 149/1000
# 0s - loss: 0.1212 - val_loss: 0.0959
# Epoch 150/1000
# 0s - loss: 0.1221 - val_loss: 0.0989
# Epoch 151/1000
# 0s - loss: 0.1213 - val_loss: 0.0952
# Epoch 152/1000
# 0s - loss: 0.1202 - val_loss: 0.0875
# Epoch 153/1000
# 0s - loss: 0.1213 - val_loss: 0.0905
# Epoch 154/1000
# 0s - loss: 0.1190 - val_loss: 0.0884
# Epoch 155/1000
# 0s - loss: 0.1200 - val_loss: 0.0963
# Epoch 156/1000
# 0s - loss: 0.1169 - val_loss: 0.0878
# Epoch 157/1000
# 0s - loss: 0.1159 - val_loss: 0.0879
# Epoch 158/1000
# 0s - loss: 0.1138 - val_loss: 0.0842
# Epoch 159/1000
# 0s - loss: 0.1133 - val_loss: 0.0851
# Epoch 160/1000
# 0s - loss: 0.1124 - val_loss: 0.0872
# Epoch 161/1000
# 0s - loss: 0.1132 - val_loss: 0.0871
# Epoch 162/1000
# 0s - loss: 0.1108 - val_loss: 0.0805
# Epoch 163/1000
# 0s - loss: 0.1112 - val_loss: 0.0799
# Epoch 164/1000
# 0s - loss: 0.1099 - val_loss: 0.0842
# Epoch 165/1000
# 0s - loss: 0.1089 - val_loss: 0.0856
# Epoch 166/1000
# 0s - loss: 0.1085 - val_loss: 0.0826
# Epoch 167/1000
# 0s - loss: 0.1087 - val_loss: 0.0765
# Epoch 168/1000
# 0s - loss: 0.1076 - val_loss: 0.0778
# Epoch 169/1000
# 0s - loss: 0.1070 - val_loss: 0.0813
# Epoch 170/1000
# 0s - loss: 0.1057 - val_loss: 0.0790
# Epoch 171/1000
# 0s - loss: 0.1095 - val_loss: 0.0827
# Epoch 172/1000
# 0s - loss: 0.1046 - val_loss: 0.0736
# Epoch 173/1000
# 0s - loss: 0.1064 - val_loss: 0.0717
# Epoch 174/1000
# 0s - loss: 0.1045 - val_loss: 0.0803
# Epoch 175/1000
# 0s - loss: 0.1038 - val_loss: 0.0818
# Epoch 176/1000
# 0s - loss: 0.1017 - val_loss: 0.0735
# Epoch 177/1000
# 0s - loss: 0.1013 - val_loss: 0.0712
# Epoch 178/1000
# 0s - loss: 0.1009 - val_loss: 0.0714
# Epoch 179/1000
# 0s - loss: 0.1000 - val_loss: 0.0733

# %%
pred = model.predict(x_test)
pred[:5]
# Out:
# array([[  1.86586077e-03,   8.40946913e-01,   1.57187268e-01],
#        [  9.97686744e-01,   2.31325789e-03,   4.80374451e-09],
#        [  9.90083575e-01,   9.91635118e-03,   2.95967322e-08],
#        [  1.77585264e-03,   9.40439880e-01,   5.77843674e-02],
#        [  5.29086901e-06,   3.91865112e-02,   9.60808218e-01]], dtype=float32)

# %% [markdown]
# ## Early Stopping and the best weight
#
# early stopping: the training will halt once the validation set no longer saw score improvements for a number of steps, the number of steps that early stopping will tolerate is calles patience
#
# store the best weight when training data

# %%
from keras.callbacks import ModelCheckpoint

model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(y.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
# save the best weights
checkpoint = ModelCheckpoint(filepath='best_weights.hdf5', verbose=0, save_best_only=True)

model.fit(x, y, validation_data=(x_test, y_test), callbacks=[monitor, checkpoint], verbose=2, epochs=1000)
model.load_weights('best_weights.hdf5')
# Out:
# Train on 150 samples, validate on 38 samples
# Epoch 1/1000
# 0s - loss: 1.2727 - val_loss: 1.1972
# Epoch 2/1000
# 0s - loss: 1.2206 - val_loss: 1.1602
# Epoch 3/1000
# 0s - loss: 1.1800 - val_loss: 1.1319
# Epoch 4/1000
# 0s - loss: 1.1463 - val_loss: 1.1136
# Epoch 5/1000
# 0s - loss: 1.1229 - val_loss: 1.1005
# Epoch 6/1000
# 0s - loss: 1.1046 - val_loss: 1.0909
# Epoch 7/1000
# 0s - loss: 1.0925 - val_loss: 1.0810
# Epoch 8/1000
# 0s - loss: 1.0798 - val_loss: 1.0690
# Epoch 9/1000
# 0s - loss: 1.0659 - val_loss: 1.0548
# Epoch 10/1000
# 0s - loss: 1.0512 - val_loss: 1.0400
# Epoch 11/1000
# 0s - loss: 1.0389 - val_loss: 1.0242
# Epoch 12/1000
# 0s - loss: 1.0218 - val_loss: 1.0071
# Epoch 13/1000
# 0s - loss: 1.0058 - val_loss: 0.9891
# Epoch 14/1000
# 0s - loss: 0.9900 - val_loss: 0.9727
# Epoch 15/1000
# 0s - loss: 0.9760 - val_loss: 0.9581
# Epoch 16/1000
# 0s - loss: 0.9634 - val_loss: 0.9465
# Epoch 17/1000
# 0s - loss: 0.9534 - val_loss: 0.9370
# Epoch 18/1000
# 0s - loss: 0.9440 - val_loss: 0.9268
# Epoch 19/1000
# 0s - loss: 0.9352 - val_loss: 0.9163
# Epoch 20/1000
# 0s - loss: 0.9242 - val_loss: 0.9063
# Epoch 21/1000
# 0s - loss: 0.9142 - val_loss: 0.8954
# Epoch 22/1000
# 0s - loss: 0.9039 - val_loss: 0.8845
# Epoch 23/1000
# 0s - loss: 0.8939 - val_loss: 0.8736
# Epoch 24/1000
# 0s - loss: 0.8841 - val_loss: 0.8632
# Epoch 25/1000
# 0s - loss: 0.8736 - val_loss: 0.8512
# Epoch 26/1000
# 0s - loss: 0.8634 - val_loss: 0.8403
# Epoch 27/1000
# 0s - loss: 0.8529 - val_loss: 0.8291
# Epoch 28/1000
# 0s - loss: 0.8428 - val_loss: 0.8177
# Epoch 29/1000
# 0s - loss: 0.8323 - val_loss: 0.8066
# Epoch 30/1000
# 0s - loss: 0.8218 - val_loss: 0.7955
# Epoch 31/1000
# 0s - loss: 0.8117 - val_loss: 0.7839
# Epoch 32/1000
# 0s - loss: 0.8015 - val_loss: 0.7724
# Epoch 33/1000
# 0s - loss: 0.7929 - val_loss: 0.7613
# Epoch 34/1000
# 0s - loss: 0.7812 - val_loss: 0.7502
# Epoch 35/1000
# 0s - loss: 0.7715 - val_loss: 0.7396
# Epoch 36/1000
# 0s - loss: 0.7612 - val_loss: 0.7295
# Epoch 37/1000
# 0s - loss: 0.7518 - val_loss: 0.7196
# Epoch 38/1000
# 0s - loss: 0.7424 - val_loss: 0.7094
# Epoch 39/1000
# 0s - loss: 0.7328 - val_loss: 0.6994
# Epoch 40/1000
# 0s - loss: 0.7245 - val_loss: 0.6896
# Epoch 41/1000
# 0s - loss: 0.7144 - val_loss: 0.6802
# Epoch 42/1000
# 0s - loss: 0.7063 - val_loss: 0.6713
# Epoch 43/1000
# 0s - loss: 0.6974 - val_loss: 0.6619
# Epoch 44/1000
# 0s - loss: 0.6887 - val_loss: 0.6525
# Epoch 45/1000
# 0s - loss: 0.6812 - val_loss: 0.6435
# Epoch 46/1000
# 0s - loss: 0.6723 - val_loss: 0.6346
# Epoch 47/1000
# 0s - loss: 0.6647 - val_loss: 0.6262
# Epoch 48/1000
# 0s - loss: 0.6569 - val_loss: 0.6182
# Epoch 49/1000
# 0s - loss: 0.6509 - val_loss: 0.6103
# Epoch 50/1000
# 0s - loss: 0.6429 - val_loss: 0.6026
# Epoch 51/1000
# 0s - loss: 0.6356 - val_loss: 0.5956
# Epoch 52/1000
# 0s - loss: 0.6291 - val_loss: 0.5886
# Epoch 53/1000
# 0s - loss: 0.6230 - val_loss: 0.5823
# Epoch 54/1000
# 0s - loss: 0.6167 - val_loss: 0.5756
# Epoch 55/1000
# 0s - loss: 0.6113 - val_loss: 0.5691
# Epoch 56/1000
# 0s - loss: 0.6063 - val_loss: 0.5630
# Epoch 57/1000
# 0s - loss: 0.6000 - val_loss: 0.5567
# Epoch 58/1000
# 0s - loss: 0.5942 - val_loss: 0.5510
# Epoch 59/1000
# 0s - loss: 0.5889 - val_loss: 0.5457
# Epoch 60/1000
# 0s - loss: 0.5848 - val_loss: 0.5405
# Epoch 61/1000
# 0s - loss: 0.5792 - val_loss: 0.5356
# Epoch 62/1000
# 0s - loss: 0.5748 - val_loss: 0.5310
# Epoch 63/1000
# 0s - loss: 0.5706 - val_loss: 0.5263
# Epoch 64/1000
# 0s - loss: 0.5663 - val_loss: 0.5220
# Epoch 65/1000
# 0s - loss: 0.5625 - val_loss: 0.5175
# Epoch 66/1000
# 0s - loss: 0.5584 - val_loss: 0.5135
# Epoch 67/1000
# 0s - loss: 0.5552 - val_loss: 0.5096
# Epoch 68/1000
# 0s - loss: 0.5512 - val_loss: 0.5058
# Epoch 69/1000
# 0s - loss: 0.5473 - val_loss: 0.5019
# Epoch 70/1000
# 0s - loss: 0.5441 - val_loss: 0.4984
# Epoch 71/1000
# 0s - loss: 0.5421 - val_loss: 0.4953
# Epoch 72/1000
# 0s - loss: 0.5385 - val_loss: 0.4919
# Epoch 73/1000
# 0s - loss: 0.5355 - val_loss: 0.4885
# Epoch 74/1000
# 0s - loss: 0.5328 - val_loss: 0.4854
# Epoch 75/1000
# 0s - loss: 0.5294 - val_loss: 0.4824
# Epoch 76/1000
# 0s - loss: 0.5273 - val_loss: 0.4795
# Epoch 77/1000
# 0s - loss: 0.5243 - val_loss: 0.4767
# Epoch 78/1000
# 0s - loss: 0.5218 - val_loss: 0.4740
# Epoch 79/1000
# 0s - loss: 0.5194 - val_loss: 0.4714
# Epoch 80/1000
# 0s - loss: 0.5172 - val_loss: 0.4688
# Epoch 81/1000
# 0s - loss: 0.5148 - val_loss: 0.4663
# Epoch 82/1000
# 0s - loss: 0.5128 - val_loss: 0.4640
# Epoch 83/1000
# 0s - loss: 0.5108 - val_loss: 0.4618
# Epoch 84/1000
# 0s - loss: 0.5086 - val_loss: 0.4595
# Epoch 85/1000
# 0s - loss: 0.5072 - val_loss: 0.4575
# Epoch 86/1000
# 0s - loss: 0.5056 - val_loss: 0.4555
# Epoch 87/1000
# 0s - loss: 0.5028 - val_loss: 0.4536
# Epoch 88/1000
# 0s - loss: 0.5017 - val_loss: 0.4518
# Epoch 89/1000
# 0s - loss: 0.4999 - val_loss: 0.4498
# Epoch 90/1000
# 0s - loss: 0.4978 - val_loss: 0.4480
# Epoch 91/1000
# 0s - loss: 0.4963 - val_loss: 0.4462
# Epoch 92/1000
# 0s - loss: 0.4945 - val_loss: 0.4445
# Epoch 93/1000
# 0s - loss: 0.4929 - val_loss: 0.4429
# Epoch 94/1000
# 0s - loss: 0.4916 - val_loss: 0.4413
# Epoch 95/1000
# 0s - loss: 0.4899 - val_loss: 0.4397
# Epoch 96/1000
# 0s - loss: 0.4893 - val_loss: 0.4381
# Epoch 97/1000
# 0s - loss: 0.4871 - val_loss: 0.4366
# Epoch 98/1000
# 0s - loss: 0.4862 - val_loss: 0.4352
# Epoch 99/1000
# 0s - loss: 0.4848 - val_loss: 0.4337
# Epoch 100/1000
# 0s - loss: 0.4833 - val_loss: 0.4325
# Epoch 101/1000
# 0s - loss: 0.4822 - val_loss: 0.4311
# Epoch 102/1000
# 0s - loss: 0.4808 - val_loss: 0.4298
# Epoch 103/1000
# 0s - loss: 0.4801 - val_loss: 0.4286
# Epoch 104/1000
# 0s - loss: 0.4791 - val_loss: 0.4272
# Epoch 105/1000
# 0s - loss: 0.4772 - val_loss: 0.4260
# Epoch 106/1000
# 0s - loss: 0.4760 - val_loss: 0.4248
# Epoch 107/1000
# 0s - loss: 0.4750 - val_loss: 0.4237
# Epoch 108/1000
# 0s - loss: 0.4738 - val_loss: 0.4225
# Epoch 109/1000
# 0s - loss: 0.4729 - val_loss: 0.4213
# Epoch 110/1000
# 0s - loss: 0.4718 - val_loss: 0.4202
# Epoch 111/1000
# 0s - loss: 0.4708 - val_loss: 0.4191
# Epoch 112/1000
# 0s - loss: 0.4698 - val_loss: 0.4182
# Epoch 113/1000
# 0s - loss: 0.4687 - val_loss: 0.4172
# Epoch 114/1000
# 0s - loss: 0.4685 - val_loss: 0.4159
# Epoch 115/1000
# 0s - loss: 0.4670 - val_loss: 0.4151
# Epoch 116/1000
# 0s - loss: 0.4660 - val_loss: 0.4140
# Epoch 117/1000
# 0s - loss: 0.4662 - val_loss: 0.4128
# Epoch 118/1000
# 0s - loss: 0.4644 - val_loss: 0.4121
# Epoch 119/1000
# 0s - loss: 0.4633 - val_loss: 0.4112
# Epoch 120/1000
# 0s - loss: 0.4621 - val_loss: 0.4100
# Epoch 121/1000
# 0s - loss: 0.4612 - val_loss: 0.4091
# Epoch 122/1000
# 0s - loss: 0.4603 - val_loss: 0.4081
# Epoch 123/1000
# 0s - loss: 0.4596 - val_loss: 0.4072
# Epoch 124/1000
# 0s - loss: 0.4591 - val_loss: 0.4063
# Epoch 125/1000
# 0s - loss: 0.4584 - val_loss: 0.4055
# Epoch 126/1000
# 0s - loss: 0.4570 - val_loss: 0.4047
# Epoch 127/1000
# 0s - loss: 0.4566 - val_loss: 0.4038
# Epoch 128/1000
# 0s - loss: 0.4555 - val_loss: 0.4029
# Epoch 129/1000
# 0s - loss: 0.4548 - val_loss: 0.4021
# Epoch 130/1000
# 0s - loss: 0.4538 - val_loss: 0.4012
# Epoch 131/1000
# 0s - loss: 0.4529 - val_loss: 0.4004
# Epoch 132/1000
# 0s - loss: 0.4534 - val_loss: 0.3998
# Epoch 133/1000
# 0s - loss: 0.4514 - val_loss: 0.3988
# Epoch 134/1000
# 0s - loss: 0.4507 - val_loss: 0.3979
# Epoch 135/1000
# 0s - loss: 0.4500 - val_loss: 0.3971
# Epoch 136/1000
# 0s - loss: 0.4493 - val_loss: 0.3963
# Epoch 137/1000
# 0s - loss: 0.4487 - val_loss: 0.3955
# Epoch 138/1000
# 0s - loss: 0.4479 - val_loss: 0.3947
# Epoch 139/1000
# 0s - loss: 0.4474 - val_loss: 0.3940
# Epoch 140/1000
# 0s - loss: 0.4464 - val_loss: 0.3933
# Epoch 141/1000
# 0s - loss: 0.4457 - val_loss: 0.3926
# Epoch 142/1000
# 0s - loss: 0.4449 - val_loss: 0.3917
# Epoch 143/1000
# 0s - loss: 0.4447 - val_loss: 0.3909
# Epoch 144/1000
# 0s - loss: 0.4436 - val_loss: 0.3902
# Epoch 145/1000
# 0s - loss: 0.4430 - val_loss: 0.3897
# Epoch 146/1000
# 0s - loss: 0.4424 - val_loss: 0.3889
# Epoch 147/1000
# 0s - loss: 0.4416 - val_loss: 0.3881
# Epoch 148/1000
# 0s - loss: 0.4409 - val_loss: 0.3875
# Epoch 149/1000
# 0s - loss: 0.4403 - val_loss: 0.3867
# Epoch 150/1000
# 0s - loss: 0.4409 - val_loss: 0.3859
# Epoch 151/1000
# 0s - loss: 0.4389 - val_loss: 0.3852
# Epoch 152/1000
# 0s - loss: 0.4386 - val_loss: 0.3847
# Epoch 153/1000
# 0s - loss: 0.4375 - val_loss: 0.3840
# Epoch 154/1000
# 0s - loss: 0.4369 - val_loss: 0.3832
# Epoch 155/1000
# 0s - loss: 0.4366 - val_loss: 0.3826
# Epoch 156/1000
# 0s - loss: 0.4356 - val_loss: 0.3819
# Epoch 157/1000
# 0s - loss: 0.4348 - val_loss: 0.3810
# Epoch 158/1000
# 0s - loss: 0.4343 - val_loss: 0.3803
# Epoch 159/1000
# 0s - loss: 0.4337 - val_loss: 0.3796
# Epoch 160/1000
# 0s - loss: 0.4329 - val_loss: 0.3789
# Epoch 161/1000
# 0s - loss: 0.4323 - val_loss: 0.3782
# Epoch 162/1000
# 0s - loss: 0.4318 - val_loss: 0.3775
# Epoch 163/1000
# 0s - loss: 0.4309 - val_loss: 0.3768
# Epoch 164/1000
# 0s - loss: 0.4305 - val_loss: 0.3759
# Epoch 165/1000
# 0s - loss: 0.4295 - val_loss: 0.3751
# Epoch 166/1000
# 0s - loss: 0.4289 - val_loss: 0.3743
# Epoch 167/1000
# 0s - loss: 0.4282 - val_loss: 0.3737
# Epoch 168/1000
# 0s - loss: 0.4272 - val_loss: 0.3730
# Epoch 169/1000
# 0s - loss: 0.4263 - val_loss: 0.3720
# Epoch 170/1000
# 0s - loss: 0.4257 - val_loss: 0.3710
# Epoch 171/1000
# 0s - loss: 0.4244 - val_loss: 0.3695
# Epoch 172/1000
# 0s - loss: 0.4232 - val_loss: 0.3681
# Epoch 173/1000
# 0s - loss: 0.4218 - val_loss: 0.3664
# Epoch 174/1000
# 0s - loss: 0.4200 - val_loss: 0.3646
# Epoch 175/1000
# 0s - loss: 0.4180 - val_loss: 0.3624
# Epoch 176/1000
# 0s - loss: 0.4153 - val_loss: 0.3596
# Epoch 177/1000
# 0s - loss: 0.4121 - val_loss: 0.3561
# Epoch 178/1000
# 0s - loss: 0.4085 - val_loss: 0.3525
# Epoch 179/1000
# 0s - loss: 0.4051 - val_loss: 0.3484
# Epoch 180/1000
# 0s - loss: 0.4002 - val_loss: 0.3447
# Epoch 181/1000
# 0s - loss: 0.3956 - val_loss: 0.3408
# Epoch 182/1000
# 0s - loss: 0.3913 - val_loss: 0.3368
# Epoch 183/1000
# 0s - loss: 0.3874 - val_loss: 0.3330
# Epoch 184/1000
# 0s - loss: 0.3822 - val_loss: 0.3283
# Epoch 185/1000
# 0s - loss: 0.3777 - val_loss: 0.3238
# Epoch 186/1000
# 0s - loss: 0.3735 - val_loss: 0.3196
# Epoch 187/1000
# 0s - loss: 0.3694 - val_loss: 0.3156
# Epoch 188/1000
# 0s - loss: 0.3652 - val_loss: 0.3118
# Epoch 189/1000
# 0s - loss: 0.3608 - val_loss: 0.3085
# Epoch 190/1000
# 0s - loss: 0.3578 - val_loss: 0.3061
# Epoch 191/1000
# 0s - loss: 0.3533 - val_loss: 0.3018
# Epoch 192/1000
# 0s - loss: 0.3489 - val_loss: 0.2975
# Epoch 193/1000
# 0s - loss: 0.3449 - val_loss: 0.2938
# Epoch 194/1000
# 0s - loss: 0.3413 - val_loss: 0.2904
# Epoch 195/1000
# 0s - loss: 0.3372 - val_loss: 0.2869
# Epoch 196/1000
# 0s - loss: 0.3336 - val_loss: 0.2834
# Epoch 197/1000
# 0s - loss: 0.3297 - val_loss: 0.2800
# Epoch 198/1000
# 0s - loss: 0.3259 - val_loss: 0.2772
# Epoch 199/1000
# 0s - loss: 0.3227 - val_loss: 0.2736
# Epoch 200/1000
# 0s - loss: 0.3197 - val_loss: 0.2715
# Epoch 201/1000
# 0s - loss: 0.3156 - val_loss: 0.2688
# Epoch 202/1000
# 0s - loss: 0.3124 - val_loss: 0.2643
# Epoch 203/1000
# 0s - loss: 0.3082 - val_loss: 0.2611
# Epoch 204/1000
# 0s - loss: 0.3051 - val_loss: 0.2577
# Epoch 205/1000
# 0s - loss: 0.3020 - val_loss: 0.2553
# Epoch 206/1000
# 0s - loss: 0.2984 - val_loss: 0.2522
# Epoch 207/1000
# 0s - loss: 0.2948 - val_loss: 0.2488
# Epoch 208/1000
# 0s - loss: 0.2919 - val_loss: 0.2458
# Epoch 209/1000
# 0s - loss: 0.2885 - val_loss: 0.2433
# Epoch 210/1000
# 0s - loss: 0.2852 - val_loss: 0.2399
# Epoch 211/1000
# 0s - loss: 0.2825 - val_loss: 0.2367
# Epoch 212/1000
# 0s - loss: 0.2790 - val_loss: 0.2352
# Epoch 213/1000
# 0s - loss: 0.2760 - val_loss: 0.2325
# Epoch 214/1000
# 0s - loss: 0.2730 - val_loss: 0.2300
# Epoch 215/1000
# 0s - loss: 0.2694 - val_loss: 0.2263
# Epoch 216/1000
# 0s - loss: 0.2667 - val_loss: 0.2234
# Epoch 217/1000
# 0s - loss: 0.2637 - val_loss: 0.2201
# Epoch 218/1000
# 0s - loss: 0.2615 - val_loss: 0.2173
# Epoch 219/1000
# 0s - loss: 0.2580 - val_loss: 0.2160
# Epoch 220/1000
# 0s - loss: 0.2555 - val_loss: 0.2129
# Epoch 221/1000
# 0s - loss: 0.2523 - val_loss: 0.2108
# Epoch 222/1000
# 0s - loss: 0.2495 - val_loss: 0.2077
# Epoch 223/1000
# 0s - loss: 0.2467 - val_loss: 0.2058
# Epoch 224/1000
# 0s - loss: 0.2442 - val_loss: 0.2026
# Epoch 225/1000
# 0s - loss: 0.2415 - val_loss: 0.2012
# Epoch 226/1000
# 0s - loss: 0.2389 - val_loss: 0.1983
# Epoch 227/1000
# 0s - loss: 0.2362 - val_loss: 0.1957
# Epoch 228/1000
# 0s - loss: 0.2344 - val_loss: 0.1928
# Epoch 229/1000
# 0s - loss: 0.2312 - val_loss: 0.1911
# Epoch 230/1000
# 0s - loss: 0.2290 - val_loss: 0.1899
# Epoch 231/1000
# 0s - loss: 0.2271 - val_loss: 0.1881
# Epoch 232/1000
# 0s - loss: 0.2248 - val_loss: 0.1837
# Epoch 233/1000
# 0s - loss: 0.2226 - val_loss: 0.1814
# Epoch 234/1000
# 0s - loss: 0.2200 - val_loss: 0.1811
# Epoch 235/1000
# 0s - loss: 0.2173 - val_loss: 0.1803
# Epoch 236/1000
# 0s - loss: 0.2154 - val_loss: 0.1776
# Epoch 237/1000
# 0s - loss: 0.2131 - val_loss: 0.1758
# Epoch 238/1000
# 0s - loss: 0.2117 - val_loss: 0.1723
# Epoch 239/1000
# 0s - loss: 0.2091 - val_loss: 0.1708
# Epoch 240/1000
# 0s - loss: 0.2067 - val_loss: 0.1698
# Epoch 241/1000
# 0s - loss: 0.2047 - val_loss: 0.1678
# Epoch 242/1000
# 0s - loss: 0.2029 - val_loss: 0.1654
# Epoch 243/1000
# 0s - loss: 0.2007 - val_loss: 0.1639
# Epoch 244/1000
# 0s - loss: 0.1989 - val_loss: 0.1626
# Epoch 245/1000
# 0s - loss: 0.1974 - val_loss: 0.1613
# Epoch 246/1000
# 0s - loss: 0.1950 - val_loss: 0.1587
# Epoch 247/1000
# 0s - loss: 0.1935 - val_loss: 0.1569
# Epoch 248/1000
# 0s - loss: 0.1914 - val_loss: 0.1547
# Epoch 249/1000
# 0s - loss: 0.1899 - val_loss: 0.1525
# Epoch 250/1000
# 0s - loss: 0.1879 - val_loss: 0.1515
# Epoch 251/1000
# 0s - loss: 0.1860 - val_loss: 0.1514
# Epoch 252/1000
# 0s - loss: 0.1845 - val_loss: 0.1504
# Epoch 253/1000
# 0s - loss: 0.1830 - val_loss: 0.1485
# Epoch 254/1000
# 0s - loss: 0.1812 - val_loss: 0.1470
# Epoch 255/1000
# 0s - loss: 0.1793 - val_loss: 0.1440
# Epoch 256/1000
# 0s - loss: 0.1784 - val_loss: 0.1412
# Epoch 257/1000
# 0s - loss: 0.1768 - val_loss: 0.1400
# Epoch 258/1000
# 0s - loss: 0.1747 - val_loss: 0.1403
# Epoch 259/1000
# 0s - loss: 0.1733 - val_loss: 0.1410
# Epoch 260/1000
# 0s - loss: 0.1724 - val_loss: 0.1400
# Epoch 261/1000
# 0s - loss: 0.1705 - val_loss: 0.1368
# Epoch 262/1000
# 0s - loss: 0.1686 - val_loss: 0.1339
# Epoch 263/1000
# 0s - loss: 0.1675 - val_loss: 0.1321
# Epoch 264/1000
# 0s - loss: 0.1664 - val_loss: 0.1310
# Epoch 265/1000
# 0s - loss: 0.1660 - val_loss: 0.1320
# Epoch 266/1000
# 0s - loss: 0.1635 - val_loss: 0.1304
# Epoch 267/1000
# 0s - loss: 0.1622 - val_loss: 0.1271
# Epoch 268/1000
# 0s - loss: 0.1609 - val_loss: 0.1259
# Epoch 269/1000
# 0s - loss: 0.1594 - val_loss: 0.1252
# Epoch 270/1000
# 0s - loss: 0.1580 - val_loss: 0.1251
# Epoch 271/1000
# 0s - loss: 0.1567 - val_loss: 0.1246
# Epoch 272/1000
# 0s - loss: 0.1557 - val_loss: 0.1237
# Epoch 273/1000
# 0s - loss: 0.1546 - val_loss: 0.1213
# Epoch 274/1000
# 0s - loss: 0.1530 - val_loss: 0.1203
# Epoch 275/1000
# 0s - loss: 0.1519 - val_loss: 0.1198
# Epoch 276/1000
# 0s - loss: 0.1506 - val_loss: 0.1181
# Epoch 277/1000
# 0s - loss: 0.1495 - val_loss: 0.1161
# Epoch 278/1000
# 0s - loss: 0.1483 - val_loss: 0.1153
# Epoch 279/1000
# 0s - loss: 0.1474 - val_loss: 0.1158
# Epoch 280/1000
# 0s - loss: 0.1463 - val_loss: 0.1139
# Epoch 281/1000
# 0s - loss: 0.1446 - val_loss: 0.1120
# Epoch 282/1000
# 0s - loss: 0.1434 - val_loss: 0.1111
# Epoch 283/1000
# 0s - loss: 0.1422 - val_loss: 0.1099
# Epoch 284/1000
# 0s - loss: 0.1415 - val_loss: 0.1079
# Epoch 285/1000
# 0s - loss: 0.1401 - val_loss: 0.1078
# Epoch 286/1000
# 0s - loss: 0.1388 - val_loss: 0.1073
# Epoch 287/1000
# 0s - loss: 0.1379 - val_loss: 0.1063
# Epoch 288/1000
# 0s - loss: 0.1364 - val_loss: 0.1053
# Epoch 289/1000
# 0s - loss: 0.1356 - val_loss: 0.1040
# Epoch 290/1000
# 0s - loss: 0.1343 - val_loss: 0.1041
# Epoch 291/1000
# 0s - loss: 0.1334 - val_loss: 0.1038
# Epoch 292/1000
# 0s - loss: 0.1327 - val_loss: 0.1016
# Epoch 293/1000
# 0s - loss: 0.1313 - val_loss: 0.1019
# Epoch 294/1000
# 0s - loss: 0.1304 - val_loss: 0.1008
# Epoch 295/1000
# 0s - loss: 0.1293 - val_loss: 0.0994
# Epoch 296/1000
# 0s - loss: 0.1284 - val_loss: 0.0980
# Epoch 297/1000
# 0s - loss: 0.1282 - val_loss: 0.0964
# Epoch 298/1000
# 0s - loss: 0.1269 - val_loss: 0.0966
# Epoch 299/1000
# 0s - loss: 0.1261 - val_loss: 0.0963
# Epoch 300/1000
# 0s - loss: 0.1254 - val_loss: 0.0956
# Epoch 301/1000
# 0s - loss: 0.1249 - val_loss: 0.0917
# Epoch 302/1000
# 0s - loss: 0.1239 - val_loss: 0.0916
# Epoch 303/1000
# 0s - loss: 0.1249 - val_loss: 0.0942
# Epoch 304/1000
# 0s - loss: 0.1222 - val_loss: 0.0910
# Epoch 305/1000
# 0s - loss: 0.1211 - val_loss: 0.0902
# Epoch 306/1000
# 0s - loss: 0.1204 - val_loss: 0.0914
# Epoch 307/1000
# 0s - loss: 0.1199 - val_loss: 0.0910
# Epoch 308/1000
# 0s - loss: 0.1193 - val_loss: 0.0882
# Epoch 309/1000
# 0s - loss: 0.1181 - val_loss: 0.0884
# Epoch 310/1000
# 0s - loss: 0.1174 - val_loss: 0.0877
# Epoch 311/1000
# 0s - loss: 0.1167 - val_loss: 0.0869
# Epoch 312/1000
# 0s - loss: 0.1162 - val_loss: 0.0867
# Epoch 313/1000
# 0s - loss: 0.1154 - val_loss: 0.0849
# Epoch 314/1000
# 0s - loss: 0.1147 - val_loss: 0.0846
# Epoch 315/1000
# 0s - loss: 0.1142 - val_loss: 0.0837
# Epoch 316/1000
# 0s - loss: 0.1137 - val_loss: 0.0847
# Epoch 317/1000
# 0s - loss: 0.1129 - val_loss: 0.0828
# Epoch 318/1000
# 0s - loss: 0.1123 - val_loss: 0.0825
# Epoch 319/1000
# 0s - loss: 0.1118 - val_loss: 0.0826
# Epoch 320/1000
# 0s - loss: 0.1110 - val_loss: 0.0814
# Epoch 321/1000
# 0s - loss: 0.1108 - val_loss: 0.0798
# Epoch 322/1000
# 0s - loss: 0.1105 - val_loss: 0.0777
# Epoch 323/1000
# 0s - loss: 0.1102 - val_loss: 0.0781
# Epoch 324/1000
# 0s - loss: 0.1091 - val_loss: 0.0785
# Epoch 325/1000
# 0s - loss: 0.1079 - val_loss: 0.0818
# Epoch 326/1000
# 0s - loss: 0.1087 - val_loss: 0.0828
# Epoch 327/1000
# 0s - loss: 0.1076 - val_loss: 0.0785
# Epoch 328/1000
# 0s - loss: 0.1067 - val_loss: 0.0760
# Epoch 329/1000
# 0s - loss: 0.1063 - val_loss: 0.0754
# Epoch 330/1000
# 0s - loss: 0.1057 - val_loss: 0.0753
# Epoch 331/1000
# 0s - loss: 0.1059 - val_loss: 0.0757
# Epoch 332/1000
# 0s - loss: 0.1046 - val_loss: 0.0730
# Epoch 333/1000
# 0s - loss: 0.1049 - val_loss: 0.0737
# Epoch 334/1000
# 0s - loss: 0.1040 - val_loss: 0.0733
# Epoch 335/1000
# 0s - loss: 0.1041 - val_loss: 0.0747
# Epoch 336/1000
# 0s - loss: 0.1027 - val_loss: 0.0729
# Epoch 337/1000
# 0s - loss: 0.1023 - val_loss: 0.0723
# Epoch 338/1000
# 0s - loss: 0.1024 - val_loss: 0.0708
# Epoch 339/1000
# 0s - loss: 0.1015 - val_loss: 0.0714
# Epoch 340/1000
# 0s - loss: 0.1014 - val_loss: 0.0726
# Epoch 341/1000
# 0s - loss: 0.1006 - val_loss: 0.0719
# Epoch 342/1000
# 0s - loss: 0.1003 - val_loss: 0.0704
# Epoch 343/1000
# 0s - loss: 0.0999 - val_loss: 0.0713
# Epoch 344/1000
# 0s - loss: 0.0997 - val_loss: 0.0714
# Epoch 00343: early stopping

# %%
pred = model.predict(x_test)
pred[:5]
# Out:
# array([[  6.30629808e-03,   8.88681173e-01,   1.05012543e-01],
#        [  9.99187529e-01,   8.12484708e-04,   1.17771098e-10],
#        [  9.90120053e-01,   9.87990107e-03,   6.11138695e-09],
#        [  7.07436772e-03,   9.50062931e-01,   4.28627096e-02],
#        [  5.92995348e-05,   5.64648025e-02,   9.43475842e-01]], dtype=float32)

# %%
pre_ = np.argmax(pred, axis=1)
pre_
# Out:
# array([1, 0, 0, 1, 2, 2, 0, 0, 1, 0, 1, 2, 1, 1, 2, 2, 1, 2, 1, 0, 0, 2, 1,
#        0, 0, 1, 0, 2, 0, 0, 1, 0, 0, 2, 1, 0, 0, 2])

# %%
act_y = np.argmax(y_test, axis=1)
act_y
# Out:
# array([1, 0, 0, 1, 2, 2, 0, 0, 1, 0, 1, 2, 1, 1, 2, 2, 1, 2, 1, 0, 0, 2, 2,
#        0, 0, 1, 0, 2, 0, 0, 1, 0, 0, 2, 1, 0, 0, 2])

# %%
metrics.accuracy_score(pre_, act_y)
# Out:
# 0.97368421052631582

# %% [markdown]
# ## mean_square_error
#
# $ RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^{n}(\hat{y}_{i} - y_{i})^2} $
